# %% [markdown]
# ##  <center>Load the PDF</center>

# %% [markdown]
# ### About this project

# %% [markdown]
# This file is intended for loading pdf files about sales, cleaning up and tokenizing the data trough regex and save them as pd.Dataframe.
# Later we merge the sales data with products on products.ipynb in order to categorize sales by products and them on fermac_analysis.ipynb we proceed with the anylises itself.

# %%
#https://www.youtube.com/watch?v=QJbbxqgwQaM
import pdfplumber
import pdfplumber, re
print(pdfplumber.__version__)
# Out:
# 0.10.1

# %%
pdf = pdfplumber.open('./data/nfs_2023.pdf')

# %% [markdown]
# ## Inspecting the document

# %%
for page in pdf.pages:
    for line in page.extract_text().splitlines():
        print(line)
# Out:
# Empresa Panatlântica S.A.
# R. Rudolfo Vontobel, 600 Distrito Industrial - Gravatai/RS CEP: 94045405
# CNPJ: 92.693.019/0001-89 IE: 0570024129 FONE: 3489 77 77
# CONSULTA NOTA FISCAL Data : 25.08.2023 - Hora: 13:28:09 - Folha : 001 / 26
# Data: 01//0/2/20
# N o t a F i s c a l E s t a b P e d i d o - S e q C l i e n t e I t e m E s p e s s u r a L a r g u r a C o m p r i m e n t o V l P e ç a V l U n i t Q t I t e m Vl Total
# 0 3 2 0 6 0 2 1 1 3 4 9 0 7 6 - 2 0 P H T R A N S CHAPA FQ 4,75 NBR6658 - 2022 4,7500 1.500,0000 3.000,0000 0,00 6,35 695,00 4.556,68
# 0 3 2 0 6 0 4 1 1 3 3 9 5 8 8 - 1 0 M E T M E T A L C I N TIRA FF BOB 0,30 G2L290 BbOL 0,3000 243,0000 0,0000 0,00 13,57 1.034,00 14.487,40
# 0 3 2 0 6 0 4 1 1 3 4 6 9 0 6 - 1 0 M E T M E T A L C I N TIRA FF BOB 0,30 G2L290 BbOL 0,3000 243,0000 0,0000 0,00 13,57 987,00 13.828,88
# 0 3 2 0 6 0 4 1 1 3 4 6 9 0 6 - 2 0 M E T M E T A L C I N TIRA FF BOB 0,35 G4RL BbOL 0,3500 250,0000 0,0000 0,00 13,57 1.032,00 14.459,38
# ...

# %% [markdown]
# ## Visualize the first Page

# %%
# p0 = pdf.pages[0]
# im = p0.to_image()
# im

# %% [markdown]
# Below, we draw rectangles around each of the char objects that pdfplumber detected.

# %%
# im.reset().draw_rects(p0.chars)

# %%
# text = page.extract_text(keep_blank_chars=True)
# print(text)

# %% [markdown]
# ### Cleanning up the data. Removing header footer and other undesirable lines.

# %%
def remove_pattern(text, pattern):
    return re.sub(pattern,'', text)

# %%
def print_data(data_list):
    for index, value in enumerate(data_list):
        print(f'The value at {index} is {value}\n\n')

# %%
# Regex pattern for "Date", "Time" and "Folha : [page_number] / [total_pages]"

extracted_pdf_data = []

header_date_pattern = r'\d{2}\.\d{2}\.\d{4} - ' #Data : 23.07.2023

time_pattern = r'Hora: \d{2}:\d{2}:\d{2} - '

page_pattern = r'Folha : \d+ / \d+'  # $ indicates the pattern is at the end of the string

search_string_1 = 'Empresa Panatlântica S.A.'

search_string_2 = 'R. Rudolfo Vontobel, 600 Distrito Industrial - Gravatai/RS CEP: 94045405' 

search_string_3 = 'CNPJ: 92.693.019/0001-89 IE: 0570024129 FONE: 3489 77 77' 

search_string_4 = 'CONSULTA NOTA FISCAL Data : ' + header_date_pattern + time_pattern + page_pattern

search_string_5 = 'N o t a F i s c a l E s t a b P e d i d o - S e q C l i e n t e I t e m E s p e s s u r a L a r g u r a C o m p r i m e n t o V l P e ç a V l U n i t Q t I t e m Vl Total'

for page in pdf.pages:
    for line in page.extract_text().splitlines():
        extracted_pdf_data.append(line)

# Using list comprehension to remove the strings that match the pattern at the end        
extracted_pdf_data = [remove_pattern(line, search_string_1) for line in extracted_pdf_data] # 'Empresa Panatlântica S.A.'
extracted_pdf_data = [remove_pattern(line, search_string_2) for line in extracted_pdf_data] # 'R. Rudolfo Vontobel, 600 Distrito Industrial - Gravatai/RS CEP: 94045405'
extracted_pdf_data = [remove_pattern(line, search_string_3) for line in extracted_pdf_data] # 'CNPJ: 92.693.019/0001-89 IE: 0570024129 FONE: 3489 77 77' 
extracted_pdf_data = [remove_pattern(line, search_string_4) for line in extracted_pdf_data] # 'CONSULTA NOTA FISCAL ' + date_pattern + time_pattern + page_pattern
extracted_pdf_data = [remove_pattern(line, search_string_5) for line in extracted_pdf_data] # 'N o t a F i s c a l E s t a b P e d i d o - S e q...'
extracted_pdf_data = [item for item in extracted_pdf_data if item.strip()]
[extracted_pdf_data.pop(index) for index, value in enumerate(extracted_pdf_data) if not 'Data' in value and len(value) <= 30] #'6.666,00 17.841,26'
extracted_pdf_data.pop(-1) #Total Geral1.691.589,00 4.546.046,08

print_data(extracted_pdf_data)
# Out:
# The value at 0 is Data: 01//0/2/20
#
#
# The value at 1 is 0 3 2 0 6 0 2 1 1 3 4 9 0 7 6 - 2 0 P H T R A N S CHAPA FQ 4,75 NBR6658 - 2022 4,7500 1.500,0000 3.000,0000 0,00 6,35 695,00 4.556,68
#
#
# The value at 2 is 0 3 2 0 6 0 4 1 1 3 3 9 5 8 8 - 1 0 M E T M E T A L C I N TIRA FF BOB 0,30 G2L290 BbOL 0,3000 243,0000 0,0000 0,00 13,57 1.034,00 14.487,40
#
#
# The value at 3 is 0 3 2 0 6 0 4 1 1 3 4 6 9 0 6 - 1 0 M E T M E T A L C I N TIRA FF BOB 0,30 G2L290 BbOL 0,3000 243,0000 0,0000 0,00 13,57 987,00 13.828,88
#
#
# The value at 4 is 0 3 2 0 6 0 4 1 1 3 4 6 9 0 6 - 2 0 M E T M E T A L C I N TIRA FF BOB 0,35 G4RL BbOL 0,3500 250,0000 0,0000 0,00 13,57 1.032,00 14.459,38
#
#
# The value at 5 is 0 3 2 0 5 9 9 1 1 3 4 7 4 8 0 - 9 0 M A Q E N G E TIRA FF BOB 0,60 SAE1006 OL - 2022 0,6000 213,0000 0,0000 0,00 7,90 2.885,00 23.532,22
#
#
# The value at 6 is Data: 01//0/3/20
#
#
# ...

# %%
extracted_pdf_data
# Out:
# ['Data: 01//0/2/20',
#  '0 3 2 0 6 0 2 1 1 3 4 9 0 7 6 - 2 0 P H T R A N S CHAPA FQ 4,75 NBR6658 - 2022 4,7500 1.500,0000 3.000,0000 0,00 6,35 695,00 4.556,68',
#  '0 3 2 0 6 0 4 1 1 3 3 9 5 8 8 - 1 0 M E T M E T A L C I N TIRA FF BOB 0,30 G2L290 BbOL 0,3000 243,0000 0,0000 0,00 13,57 1.034,00 14.487,40',
#  '0 3 2 0 6 0 4 1 1 3 4 6 9 0 6 - 1 0 M E T M E T A L C I N TIRA FF BOB 0,30 G2L290 BbOL 0,3000 243,0000 0,0000 0,00 13,57 987,00 13.828,88',
#  '0 3 2 0 6 0 4 1 1 3 4 6 9 0 6 - 2 0 M E T M E T A L C I N TIRA FF BOB 0,35 G4RL BbOL 0,3500 250,0000 0,0000 0,00 13,57 1.032,00 14.459,38',
#  '0 3 2 0 5 9 9 1 1 3 4 7 4 8 0 - 9 0 M A Q E N G E TIRA FF BOB 0,60 SAE1006 OL - 2022 0,6000 213,0000 0,0000 0,00 7,90 2.885,00 23.532,22',
#  'Data: 01//0/3/20',
#  '0 3 2 2 0 6 9 1 1 3 5 0 1 8 2 - 1 0 S A S P L A S T I TIRA FQ DEC BOB 2,65 NBR6658 OL 2,6500 22,0000 0,0000 0,00 8,60 1.411,00 12.528,97',
# ...

# %%
date_pattern = r'\s(\d{2}\//\d{1}/\d{1}/\d{2})?' # 'Data: 01//0/6/20

Date = []

for index, line in enumerate(extracted_pdf_data):
    if 'Data' in line:
        
        date = re.sub(r'Data:',"",extracted_pdf_data[index]).strip().replace("/20","//2023").replace("//","-").replace("/", "")

    else:

        Date.append(date)
Date
# Out:
# ['01-02-2023',
#  '01-02-2023',
#  '01-02-2023',
#  '01-02-2023',
#  '01-02-2023',
#  '01-03-2023',
#  '01-03-2023',
#  '01-03-2023',
#  '01-08-2023',
#  '01-08-2023',
#  '01-08-2023',
#  '01-08-2023',
#  '01-08-2023',
#  '01-08-2023',
#  '01-08-2023',
#  '01-08-2023',
#  '01-08-2023',
#  '01-08-2023',
#  '02-01-2023',
#  '02-02-2023',
#  '02-02-2023',
#  '02-03-2023',
#  '02-03-2023',
#  '02-03-2023',
#  '02-03-2023',
#  '02-03-2023',
#  '02-03-2023',
#  '02-06-2023',
#  '02-06-2023',
#  '02-06-2023',
#  '02-06-2023',
#  '02-06-2023',
#  '03-01-2023',
#  '03-02-2023',
#  '03-02-2023',
#  '03-02-2023',
#  '03-02-2023',
#  '03-02-2023',
#  '03-03-2023',
#  '03-03-2023',
#  '03-04-2023',
#  '03-04-2023',
#  '03-04-2023',
#  '03-05-2023',
#  '03-05-2023',
#  '04-05-2023',
#  '04-05-2023',
#  '04-07-2023',
#  '04-07-2023',
#  '04-07-2023',
#  '04-07-2023',
#  '04-07-2023',
#  '04-07-2023',
#  '04-08-2023',
#  '04-08-2023',
#  '04-08-2023',
#  '05-01-2023',
#  '05-01-2023',
# ...

# %%
date_pattern = r'Data:\s(\d{2}\//\d{1}/\d{1}/\d{2})?'
# extracted_pdf_data = [remove_pattern(line, date_pattern) for line in extracted_pdf_data]
[extracted_pdf_data.pop(index) for index, value in enumerate(extracted_pdf_data) if 'Data' in value]
# extracted_pdf_data = [remove_pattern(line, 'Data:') for line in extracted_pdf_data]
# extracted_pdf_data = [item for item in extracted_pdf_data if item.strip()]

extracted_pdf_data
# Out:
# ['0 3 2 0 6 0 2 1 1 3 4 9 0 7 6 - 2 0 P H T R A N S CHAPA FQ 4,75 NBR6658 - 2022 4,7500 1.500,0000 3.000,0000 0,00 6,35 695,00 4.556,68',
#  '0 3 2 0 6 0 4 1 1 3 3 9 5 8 8 - 1 0 M E T M E T A L C I N TIRA FF BOB 0,30 G2L290 BbOL 0,3000 243,0000 0,0000 0,00 13,57 1.034,00 14.487,40',
#  '0 3 2 0 6 0 4 1 1 3 4 6 9 0 6 - 1 0 M E T M E T A L C I N TIRA FF BOB 0,30 G2L290 BbOL 0,3000 243,0000 0,0000 0,00 13,57 987,00 13.828,88',
#  '0 3 2 0 6 0 4 1 1 3 4 6 9 0 6 - 2 0 M E T M E T A L C I N TIRA FF BOB 0,35 G4RL BbOL 0,3500 250,0000 0,0000 0,00 13,57 1.032,00 14.459,38',
#  '0 3 2 0 5 9 9 1 1 3 4 7 4 8 0 - 9 0 M A Q E N G E TIRA FF BOB 0,60 SAE1006 OL - 2022 0,6000 213,0000 0,0000 0,00 7,90 2.885,00 23.532,22',
#  '0 3 2 2 0 6 9 1 1 3 5 0 1 8 2 - 1 0 S A S P L A S T I TIRA FQ DEC BOB 2,65 NBR6658 OL 2,6500 22,0000 0,0000 0,00 8,60 1.411,00 12.528,97',
# ...

# %%
len(extracted_pdf_data)
# Out:
# 400

# %%
import pandas as pd

NF = []
Est = []
Order = []
Client = []
Descrip = []
Esp = []
Larg = []
Comp = []
Piece_price = []
Real_Kg = [] 
Quantity = []
Total = []


nf_pattern = r'(\d{1}\s\d{1}\s\d{1}\s\d{1}\s\d{1}\s\d{1}\s\d{1})' # 0 3 1 9 2 0 3

est_pattern = r'(\s\d{1}\s\d{1})' # 1 1

order_pattern = r'(\s\d\s\d\s\d?\s?\d?\s?\d?\s?\d?\s?\-\s\d\s\d\s?\d?)?'

# order_pattern = r'(\s\d+(?:\s+\d+)*\s*-\s*\d+(?:\s+\d+))?' # 1 2 2 3 - 3 0

keywords = ['TIRA', 'CHAPA', 'PECA', 'FLANGE', 'TELHA', 'TR', 'PERFIL', 'BOB', 'BLANK', 'FITA', 'CH', 'CUMEEIRA', 'TUBO', 'PONTA']

client = r'([A-Z0-9\.\'\"\/\s\-]+?)(?=\s(?:' + '|'.join(map(re.escape, keywords)) + r'))'

description = r'(\s(?:' + '|'.join(map(re.escape, keywords)) + r')\s[A-Z0-9\<\>\=\/\s+]*\d{1,2}\,\d{2}\s+[A-Za-z0-9\-\=\>\<\/\,\s]+(?=\s\d{1,3}\,\d{4}))'

esp = r'(\s\d+\,\d{4})'

larg = r'(\b(?:\s\d\.\d{3})(?:\,\d{4})?|(?:\s\d{1,3})(?:\,\d{4})?\b)' #70,5000 - 225,0000 - 1.200,0000

comp = r'(\b(?:\s\d\d?\.\d{3})(?:\,\d{4})?|(?:\s\d{1,3})(?:\,\d{4})?\b)' #3.000,0000 - 0,0000 - 6.000,0000

vl_pç = r'(\b(?:\s\d{1,3}\,\d{2}))'

price = r'(\b(?:\s\d{1,2}\,\d{2}))'

quantity = r'(\b(?:\s\d\d?\d?\.\d{3})(?:\,\d{2})?|(?:\s\d{1,3})(?:\,\d{2})?\b)'

total  =   r'(\b(?:\s\d{1,4}\.\d{3})(?:\,\d{2})?|(?:\s\d{1,3})(?:\,\d{2})?\b)'


pattern = re.compile(nf_pattern + est_pattern + 
                   order_pattern + client  + 
                     description + esp + larg + comp + 
                     vl_pç + price + quantity + total
                    )

for index, line in enumerate(extracted_pdf_data):
        match = pattern.search(line)
    
        if match:
            NF.append(match[1].replace(" ",""))
            Est.append(match[2].replace(" ",""))
#             Order.append(match.group(3))
            Order.append(match.group(3).replace(" ",""))
            Client.append(match.group(4).replace(" ",""))
            Descrip.append(match.group(5))
            Esp.append(match.group(6).strip())
            Larg.append(match.group(7).strip())
            Comp.append(match.group(8).strip())
            Piece_price.append(match.group(9).strip())
            Real_Kg.append(match.group(10).strip())
            Quantity.append(match.group(11).strip())
            Total.append(match.group(12).strip())
#             print(match.groups())

        else:
            NF.append('None')
            Est.append('None')
            Order.append('None')
            Client.append('None')
            Descrip.append('None')
            Esp.append('None')
            Larg.append('None')
            Comp.append('None')
            Piece_price.append('None')
            Real_Kg.append('None')
            Quantity.append('None')
            Total.append('None')
            

data = {'Date': Date,
        'NF': NF,
        'Est': Est,
        'Order': Order,
        'Client': Client,
        'Descrip': Descrip,
        'Esp': Esp,
        'Larg': Larg,
        'Comp': Comp,
        'Piece_price': Piece_price,
        'Real_Kg': Real_Kg, 
        'Quantity': Quantity,
        'Total': Total
        }
all_data = pd.DataFrame(data)

print(data)
# Out:
# {'Date': ['01-02-2023', '01-02-2023', '01-02-2023', '01-02-2023', '01-02-2023', '01-03-2023', '01-03-2023', '01-03-2023', '01-08-2023', '01-08-2023', '01-08-2023', '01-08-2023', '01-08-2023', '01-08-2023', '01-08-2023', '01-08-2023', '01-08-2023', '01-08-2023', '02-01-2023', '02-02-2023', '02-02-2023', '02-03-2023', '02-03-2023', '02-03-2023', '02-03-2023', '02-03-2023', '02-03-2023', '02-06-2023', '02-06-2023', '02-06-2023', '02-06-2023', '02-06-2023', '03-01-2023', '03-02-2023', '03-02-2023', '03-02-2023', '03-02-2023', '03-02-2023', '03-03-2023', '03-03-2023', '03-04-2023', '03-04-2023', '03-04-2023', '03-05-2023', '03-05-2023', '04-05-2023', '04-05-2023', '04-07-2023', '04-07-2023', '04-07-2023', '04-07-2023', '04-07-2023', '04-07-2023', '04-08-2023', '04-08-2023', '04-08-2023', '05-01-2023', '05-01-2023', '05-01-2023', '05-01-2023', '05-01-2023', '05-01-2023', '05-01-2023', '05-04-2023', '05-04-2023', '05-04-2023', '05-04-2023', '05-05-2023', '05-06-2023', '05-06-2023', '05-06-2
# ...

# %%
# Determine column widths
column_widths = {key: max(len(key), max(len(str(item)) for item in values)) for key, values in data.items()}

# Print the table header
header = '| ' + ' | '.join(f"{key: <{column_widths[key]}}" for key in data.keys()) + ' |'
separator = '+' + '+'.join('-' * (column_widths[key] + 2) for key in data.keys()) + '+'
print(separator)
print(header)
print(separator)

# Print the table rows
for i in range(len(data['Date'])):
    row = '| ' + ' | '.join(f"{data[key][i]: <{column_widths[key]}}" for key in data.keys()) + ' |'
    print(row)
    print(separator)
# Out:
# +------------+---------+-----+------------+-------------+-----------------------------------------+---------+------------+------------+-------------+---------+-----------+------------+
# | Date       | NF      | Est | Order      | Client      | Descrip                                 | Esp     | Larg       | Comp       | Piece_price | Real_Kg | Quantity  | Total      |
# +------------+---------+-----+------------+-------------+-----------------------------------------+---------+------------+------------+-------------+---------+-----------+------------+
# | 01-02-2023 | 0320602 | 11  | 349076-20  | PHTRANS     |  CHAPA FQ 4,75 NBR6658 - 2022           | 4,7500  | 1.500,0000 | 3.000,0000 | 0,00        | 6,35    | 695,00    | 4.556,68   |
# +------------+---------+-----+------------+-------------+-----------------------------------------+---------+------------+------------+-------------+---------+-----------+------------+
# ...

# %%
all_data
# Out:
#            Date       NF Est      Order       Client  \
# 0    01-02-2023  0320602  11  349076-20      PHTRANS
# 1    01-02-2023  0320604  11  339588-10  METMETALCIN
# 2    01-02-2023  0320604  11  346906-10  METMETALCIN
# 3    01-02-2023  0320604  11  346906-20  METMETALCIN
# 4    01-02-2023  0320599  11  347480-90      MAQENGE
# ..          ...      ...  ..        ...          ...
# 395  31-05-2023  0326685  11  355118-80    ALCASTS/A
# 396  31-05-2023  0326687  11  355053-10  ASPIRAZIONE
# 397  31-05-2023  0326687  11  355053-20  ASPIRAZIONE
# 398  31-07-2023  0329710  11  358083-10  METMETALCIN
# 399  31-07-2023  0329710  11  358083-50  METMETALCIN
#
#                                  Descrip     Esp        Larg        Comp  \
# 0           CHAPA FQ 4,75 NBR6658 - 2022  4,7500  1.500,0000  3.000,0000
# 1           TIRA FF BOB 0,30 G2L290 BbOL  0,3000    243,0000      0,0000
# 2           TIRA FF BOB 0,30 G2L290 BbOL  0,3000    243,0000      0,0000
# ...

# %%
all_data.to_csv('data/2023.csv')

# %%
data["Descrip"]
# Out:
# [' CHAPA FQ 4,75 NBR6658 - 2022',
#  ' TIRA FF BOB 0,30 G2L290 BbOL',
#  ' TIRA FF BOB 0,30 G2L290 BbOL',
#  ' TIRA FF BOB 0,35 G4RL BbOL',
#  ' TIRA FF BOB 0,60 SAE1006 OL - 2022',
#  ' TIRA FQ DEC BOB 2,65 NBR6658 OL',
#  ' TIRA ZC BOB 1,25 NBR7008 ZC CR MI REV',
#  ' TIRA FF BOB 0,60 SAE1006 OL - 2022',
#  ' TIRA ZC BOB 1,11 NBR7008 ZC CR MI RV Z',
#  ' TIRA ZC BOB 1,55 NBR7008 ZC CR MI REV',
#  ' TIRA ZC BOB 1,55 NBR7008 ZC CR MI REV',
#  ' TIRA FF BOB 0,35 G4RL BbOL',
#  ' TIRA ZC BOB 1,25 NBR7008 ZC CR MI REV',
#  ' TIRA ZC BOB 1,25 NBR7008 ZC CR MI REV',
#  ' TIRA ZC BOB 1,24 NBR7008 ZC CR MI RV Z',
#  ' TIRA FF BOB 0,60 SAE1006 OL',
#  ' TIRA FF BOB 0,35 G4RL BbOL',
#  ' TIRA FF BOB 0,30 G4RL BbOL',
#  ' TIRA FF BOB 0,35 G4RL BbOL',
#  ' TIRA ZC BOB 1,55 NBR7008 ZC CR MI REV',
#  ' TIRA FF BOB 1,50 NBR6658 OL - 2022',
#  ' TIRA ZC BOB 1,25 NBR7008 ZC CR MI REV',
#  ' TIRA ZC BOB 1,25 NBR7008 ZC CR MI REV',
#  ' CHAPA GR LCG 25,00 ASTM A 36',
#  ' TIRA FF BOB 0,35 G4RL BbOL',
# ...

# %%
data
# Out:
# {'Date': ['01-02-2023',
#   '01-02-2023',
#   '01-02-2023',
#   '01-02-2023',
#   '01-02-2023',
#   '01-03-2023',
#   '01-03-2023',
#   '01-03-2023',
#   '01-08-2023',
#   '01-08-2023',
#   '01-08-2023',
#   '01-08-2023',
#   '01-08-2023',
#   '01-08-2023',
#   '01-08-2023',
#   '01-08-2023',
#   '01-08-2023',
#   '01-08-2023',
#   '02-01-2023',
#   '02-02-2023',
#   '02-02-2023',
#   '02-03-2023',
#   '02-03-2023',
#   '02-03-2023',
#   '02-03-2023',
#   '02-03-2023',
#   '02-03-2023',
#   '02-06-2023',
#   '02-06-2023',
#   '02-06-2023',
#   '02-06-2023',
#   '02-06-2023',
#   '03-01-2023',
#   '03-02-2023',
#   '03-02-2023',
#   '03-02-2023',
#   '03-02-2023',
#   '03-02-2023',
#   '03-03-2023',
#   '03-03-2023',
#   '03-04-2023',
#   '03-04-2023',
#   '03-04-2023',
#   '03-05-2023',
#   '03-05-2023',
#   '04-05-2023',
#   '04-05-2023',
#   '04-07-2023',
#   '04-07-2023',
#   '04-07-2023',
#   '04-07-2023',
#   '04-07-2023',
#   '04-07-2023',
#   '04-08-2023',
#   '04-08-2023',
# ...

# %%
len(Date)
# Out:
# 400

# %%
len(NF)
# Out:
# 400

# %%
len(Est)
# Out:
# 400

# %%
len(Order)
# Out:
# 400

# %%
len(Client)
# Out:
# 400

# %%
len(Descrip)
# Out:
# 400

# %%
len(Esp)
# Out:
# 400

# %%
len(Larg)
# Out:
# 400

# %%
len(Comp)
# Out:
# 400

# %%
len(Piece_price)
# Out:
# 400

# %%
len(Real_Kg)
# Out:
# 400

# %%
len(Quantity)
# Out:
# 400

# %%
len(Total)
# Out:
# 400

# %%
from collections import Counter
counter = Counter(data['Client'])
counter
# Out:
# Counter({'PHTRANS': 3,
#          'METMETALCIN': 76,
#          'MAQENGE': 34,
#          'SASPLASTI': 12,
#          'ALCAST': 5,
#          'METALMATRIX': 49,
#          'FLANTECH': 105,
#          'METALSTAMP': 16,
#          'MOFERKO': 19,
#          'ACOPLANO': 11,
#          'LUPEME': 12,
#          'G3INDUSTRIA': 2,
#          'KIFIXINDUST': 7,
#          'METCOSBI': 5,
#          'KEKO': 7,
#          'METCRESPAR': 10,
#          'UTIMIL': 4,
#          'GS': 1,
#          'CIRNA': 3,
#          'VIEMME': 5,
#          'RALKY': 2,
#          'ASPIRAZIONE': 3,
#          'ALCASTS/A': 9})

# %%
# Import information about sales invoices

csv_files = ['./data/2007.csv', './data/2008.csv','./data/2009.csv',
        './data/2010.csv','./data/2011.csv','./data/2012.csv',
         './data/2013.csv','./data/2014.csv','./data/2015.csv',
         './data/2016.csv','./data/2017.csv', './data/2018.csv',
         './data/2019.csv','./data/2020.csv','./data/2021.csv',
        './data/2022.csv','./data/2023.csv']

dataframes = [pd.read_csv(file_path) for file_path in csv_files]

sales_data = pd.concat(dataframes, ignore_index=True)

# %%
sales_data.to_csv('data/sales_data.csv', index = False)

# %%
sales_data
# Out:
#        Unnamed: 0        Date       NF Est      Order       Client  \
# 0               0  01-06-2007  0319203  11    1223-30       JRIND.
# 1               1  01-06-2007  0319202  11    3350-20       JRIND.
# 2               2  01-06-2007  0319187  11    4737-10        FORMA
# 3               3  01-08-2007  0323897  11    9477-10  ENIOSCARIOT
# 4               4  01-08-2007  0323897  11    9477-20  ENIOSCARIOT
# ...           ...         ...      ...  ..        ...          ...
# 18962         395  31-05-2023   326685  11  355118-80    ALCASTS/A
# 18963         396  31-05-2023   326687  11  355053-10  ASPIRAZIONE
# 18964         397  31-05-2023   326687  11  355053-20  ASPIRAZIONE
# 18965         398  31-07-2023   329710  11  358083-10  METMETALCIN
# 18966         399  31-07-2023   329710  11  358083-50  METMETALCIN
#
#                                    Descrip     Esp        Larg        Comp  \
# 0         CHAPA GR LTQ DEC 6,30 NBR8300 OL  6,3000  1.200,0000  3.000,0000
# ...
